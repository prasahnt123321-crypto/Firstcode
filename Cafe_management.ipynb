# %% [markdown]
# <a href="https://colab.research.google.com/github/prasahnt123321-crypto/Firstcode/blob/main/Cafe_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
menu = {"Pizza":40,
        "Pasta":50,
        "Bargur":80,
        "Salad":70,
        "Coffe":80
}
#greet
print("Wellcome to python restaurant")
print("Pizza:Rs40\nPasta:Rs50\nBargur:Rs80\nSalad:Rs70\nCoffe:Rs80")
Total_ammount = 0
item_1 = input("Enter item what youwant to take : ")
if item_1 in menu:
    print(f"enjoy your {item_1}")
    Total_ammount += menu[item_1]
    print(f"your bill is ={Total_ammount} ")
else:
  print(f"sorry sir {item_1}not avaialable")
another_item = input("do you want somthing else? (yes/no)")
if another_item == "yes":
    item_2 = input("Enter item what you want to take : ")
    if item_2 in menu:
      print(f"enjoy your {item_2}")
      Total_ammount += menu[item_2]
      print(f"total bill is {Total_ammount}")
    else:
      print(f"sorry sir {item_2} not avaliable")
else:
  print("okey sir thank you so much to come my restaurent")
# Out:
# Wellcome to python restaurant
# Pizza:Rs40
# Pasta:Rs50
# Bargur:Rs80
# Salad:Rs70
# Coffe:Rs80
# Enter item what youwant to take : Pasta
# enjoy your Pasta
# your bill is =50
# do you want somthing else? (yes/no)no
# okey sir thank you so much to come my restaurent
